# %%
import ecdsa
import random
import json
import numpy as np
import time
import hashlib
from ecdsa import SigningKey,VerifyingKey,BadSignatureError
import asyncio
import heapq

# %%
MIN_AMOUNT=1000
MAX_AMOUTN=10000
MIN_HASHRATE=1000
MAX_HASHRATE=10000
MASTETNODES_NUMS=100
REGION_NUMS=32
POW_NUMS=21
VERIFY_NUMS=11
UTXO_WEIGHT_DELTA=0.1
MAX_NONCE = 2 ** 32
VERIFY_TIME=10
MAX_BLOCKHEIGHT=100
ELECT_GAP=10
VERIFY_GAP=25
POW_DIFF=15
MINUPTIME=3600

# %%
class BlockChain:
    def __init__(self):
        self.blockheight=0
        self.version='00000010'
        self.prevblockhash='00000000000000000000000000000701'
        self.merkleroot='00000000000000000000000000001994'
        self.timestamp=hex(int(time.time()))[2:]
        self.target='00000010'
        self.blockheader=self.getBlockheader()
    
    def getBlockheader(self):
        return self.version+self.prevblockhash+self.merkleroot+self.timestamp+self.target
        
    def getDifficulty(self):
        diff=POW_DIFF
        return diff
    
    def getPrevblockhash(self):
        return self.prevblockhash
    
    def getBlockheight(self):
        return self.blockheight
    
    def nextBlock(self,blockhash):
        self.blockheight+=1
        self.version=self.version
        self.prevblockhash=blockhash
        self.merkleroot=''.join(random.choice('0123456789abcdef') for _ in range(32))
        self.timestamp=hex(int(time.time()))[2:]
        self.target=self.target
        self.blockheader=self.getBlockheader()

# %%
class Masternode(BlockChain):
    def __init__(self,utxoamount,hashrate,externalip,privkey,txid):
        super(Masternode,self).__init__()
        self.hashrate=hashrate                #节点宣称算力
        self.externalip=externalip            #节点IP
        self.privkey=privkey                  #节点私钥 - 不广播
        self.txid=txid                        #节点txid - 验证抵押金，识别ID
        self.utxoamount=utxoamount            #节点抵押货币
        self.publickey=self.generatePublickey(self.privkey) #节点公钥

    def generatePublickey(self,privkey):
        return privkey.get_verifying_key()
        
    def proof_of_work(self,header, difficulty_bits):
        target = 2 ** (256 - difficulty_bits)
        for nonce in range(MAX_NONCE):
            hash_result = hashlib.sha256((str(header) + str(nonce)).encode('utf-8')).hexdigest()
            if int(hash_result, 16) < target:
                return (hash_result, nonce)
        return False
                
    async def mining(self):
        blockheader=self.getBlockheader()
        difficulty_bits=self.getDifficulty()
        hash_result,nonce=self.proof_of_work(blockheader,difficulty_bits)
        await asyncio.sleep(random.uniform(0,1))
        return hash_result,nonce,time.time()

    async def proveHashrate(self):
        blockheader=self.getPrevblockhash+self.txid
        endblock=self.getBlockheight()+VERIFY_TIME
        nonces=[]
        while self.getBlockheight()<endblock:
            blockhash,nonce=self.proof_of_work(blockheader,difficulty_bits)
            blockheader=blockhash
            nonces.append(nonce)
        await asyncio.sleep(random.uniform(0,1))
        return nonces

    def verifyHashrate(self,node,nonces):
        header=self.blockhash+node.txid
        for nonce in nonces:
            hash_result = hashlib.sha256((str(header) + str(nonce)).encode('utf-8')).hexdigest()
            if int(hash_result, 16) > target:
                return False
            header=hash_result
        return True
    
    def sign(self,message):
        return self.privkey.sign(message)
    
    def verify(self,signature,message,verifykey):
        return verifykey.verify(signature,message)
    
    def verifyStake(self,node):
        is_node_txid_upsent=True
        is_txid_more_than_stake=True
        return is_node_txid_upsent*is_txid_more_than_stake
    
    def ping(self,node,mn):                                            #节点间连接速度
        return random.uniform(MIN_PING,MAX_PING)
    
    def chosePartners(self,node,PartMN):                               #邀请小组成员
        connectivity={}
        if len(PartMN)<=2:
            return list(PartMN)
        available_mn = [mn for mn in PartMN if abs(int(mn.txid,16)-int(node.txid,16)+int(self.blockhash,16))<2**10 and mn!=node]
        if len(available_mn)<=2:available_mn=[mn for mn in PartMN if mn!=node]
        for mn in available_mn:
            connectivity[mn]=self.ping(node,mn)
        sorted_connectivity=sorted(connectivity.items(), key=lambda item:item[1])
        return [node,sorted_connectivity[0][0],sorted_connectivity[1][0]]

# %%
class ListNode(Masternode):
    def __init__(self,utxoamount,hashrate,externalip,privkey,txid,uptime):
        super(ListNode,self).__init__(utxoamount,hashrate,externalip,privkey,txid)
        self.uptime=uptime                    #节点上线时间
        self.level=0                          #节点选举等级
        self.region= -1
        self.father=None                      #父节点
        self.children=None                    #子节点
        
    def updateLevel(self,level):
        self.level=level
    
    def updateRegion(self,region):
        self.region=region
        
    def updateFather(self,father):
        self.father=father

    def updateChildren(self,children):
        self.children=children
            
    def updateUptime(self,uptime):
        self.uptime=uptime

# %%
class Matrix(BlockChain):
    def __init__(self):
        super(Matrix,self).__init__()
        self.global_list=self.generateMN(MASTETNODES_NUMS)
        self.pow_nodes=random.sample(list(self.global_list.values()),21)
        self.verify_nodes=random.sample(list(self.global_list.values()),11)
        
    def generateMN(self,nums):          #生成主节点列表
        global_list = {}
        for i in range(nums):
            utxoamount = random.randint(MIN_AMOUNT, MAX_AMOUTN)
            hashrate = random.uniform(MIN_HASHRATE, MAX_HASHRATE)
            externalip = '.'.join([str(random.randint(0, 255)) for _ in range(4)])
            privkey = SigningKey.generate()
            txid= ''.join(random.choice('0123456789abcdef') for _ in range(32)) 
            uptime = time.time()-random.randint(0,100000)
            global_list[txid]=ListNode(utxoamount,hashrate, externalip, privkey, txid,uptime)
        return global_list
    
    def clearAll(self):
        for node in self.global_list.values():
            node.updateLevel(0)
            node.updateChildren(None)
            node.updateFather(None)
            node.updateRegion(-1)

    def dividedRegions(self):
        regions={}
        region_num=0
        for item in sorted(self.global_list.items(),key=lambda item:item[1].utxoamount*item[1].hashrate):
            item[1].updateRegion(region_num)
            region_num=(region_num+1)%REGION_NUMS
            if region_num not in regions:
                regions[region_num]=[] 
            regions[region_num].append(item[1])
        return regions
    
    def groupPK(self,group):
        timestamp=int(self.timestamp,16)
        utxo_weights=[max(float(node.utxoamount)*(timestamp-node.uptime)*node.hashrate,UTXO_WEIGHT_DELTA) for node in group]
        p=[float(w)/sum(utxo_weights) for w in utxo_weights]
        winner=np.random.choice(group,1,p)[0]
        return winner
        
    def regionElections(self,region):
        select_pool=[]
        random.seed(int(self.prevblockhash[:8],16))
        rounds=0
        while True:
            for node in region:
                if node.level==rounds: #and self.timestamp-node.uptime>MINUPTIME:
                    select_pool.append(node)
            if len(select_pool)==1:
                winner=select_pool[0]
                winner.updateUptime(winner.uptime+(int(self.timestamp,16)-winner.uptime)/2)
                return select_pool[0]
            while select_pool:
                if len(select_pool)>=3:
                    group=random.sample(select_pool,3)
                else:
                    group=select_pool
                winner=self.groupPK(group)
                children=[node for node in group if node!=winner]
                winner.updateLevel(rounds+1)
                winner.updateChildren(children)
                for node in children:
                    node.updateFather(winner)
                for node in group:
                    select_pool.remove(node)
            rounds+=1
        return False
                
            
    def elect(self):
        self.clearAll()
        regions=self.dividedRegions()
        pow_nodes=[]
        verify_nodes=[]
        for i in range(REGION_NUMS):
            if i<POW_NUMS:
                pow_nodes.append(self.regionElections(regions[i]))
            else:
                verify_nodes.append(self.regionElections(regions[i]))
        return pow_nodes,verify_nodes
    
    async def powNextblock(self):
        tasks=[node.mining() for node in self.pow_nodes]
        results=await asyncio.gather(*tasks)
        winner=-1
        blockhash=-1
        mintime=time.time()
        for i in range(POW_NUMS):
            hash_result,nonce,timestamp=results[i]
            if timestamp<mintime:
                blockhash,winner,mintime=hash_result,i,timestamp
        return blockhash,winner
    
    async def verifyAll(self):
        node.p
    
    def run(self):
        for blockheight in range(MAX_BLOCKHEIGHT):
            loop=asyncio.new_event_loop()
            blockhash,winner=loop.run_until_complete(self.powNextblock())
            loop.close()
            if blockheight%ELECT_GAP==7:
                self.pow_nodes,self.verify_nodes=self.elect()
                print(''.join('-' for _ in range(50)))
                print('POW_NODES: '+' '.join(node.txid for node in self.pow_nodes))
                print('VERYFI_NODES: '+' '.join(node.txid for node in self.verify_nodes))
                print(''.join('-' for _ in range(50)))
            if blockheight%VERIFY_GAP==3:
                pass
            self.nextBlock(blockhash)
            for node in self.global_list.values():
                node.nextBlock(blockhash)
            print('blockheight: '+str(self.blockheight),'winner: '+self.pow_nodes[winner].txid,'blockhash: '+blockhash)

# %%
matrix=Matrix()
matrix.run()
# Out:
# blockheight: 1 winner: b8554490c37801b91ee5509b32364b90 blockhash: 0001a05209f38b86422c785d4f9ca51539686cee6174f7a77af99505a8317f9c
# blockheight: 2 winner: f0f36615579c8e23ca6c11671ae7213b blockhash: 0000361ee8ef4805bfd6fb1f55e13c547312059d499cfe75e66f54874732707d
# blockheight: 3 winner: 8ce7576cc7ffffd85e0c619c54121542 blockhash: 000051fcf4fc7ab8613adcc6e64ae5bbce71009a6b8fde8812bc7a7fdcc2b077
# blockheight: 4 winner: f0f36615579c8e23ca6c11671ae7213b blockhash: 0001d249acde87e0684f14717c344c773c737ac799101dab9567943dded153d9
# blockheight: 5 winner: 7478b3926b58c836436f145d6140d967 blockhash: 0000406b1922f0a879447c6082b441c6f0f1105f9d439f75a9496f537cc29ea0
# blockheight: 6 winner: 1a2d7e4bdc48de3854a16387f12db2ec blockhash: 0000f268e8fc747a759513f30574fc11d40f71dd788869165ff548aa25bd5e97
# blockheight: 7 winner: 8849dbd4fa9e19afa6705a05337eb7dd blockhash: 0001e763bd2477614a9e1edf7ec724a56f60f755621d6ef8ca82cb396d14910f
# --------------------------------------------------
# POW_NODES: af15d2a6cc7c5215ebe44921f11e43ae 7748a130899903a079a4d630674ae892 d1b76e1c84e64051506efdd21810fa32 d80acc658a535f45c4a3b16136be6f74 097e9804b11ec53f67beff70279b7e2c 7c455fe84557fae40188787df071dc67 e26fcb9daf7c1de62137b5454b4cf555 9e6596435f2206a0e61b6214cb5214ba 2a6669e7f7993c819533877c1455dd7d 417bb4ed50894b21207add3526caa834 c8e76a9a71ea86150aeed68c32a5507c 099f2f73519fbe1190bd53c2d118cda2 b9a4eae1fddeddf713c775d7ff43ff99 b8554490c37801b91ee5509b32364b90 22f7cfb4c5902d998ec623fe715b81a3 74408035bd9dd31b26c21ad27e224da5 86f3b81c06303cd8a933704846eef197 f0f36615579c8e23ca6c11671ae7213b 6b544a6fd4a82030efcb89b08dd3fe5a 7ce4d1570fd82f4ae2805ba0c4c0cb16 2a945c61935115458a7a2ef4df5fed9f
# VERYFI_NODES: 94fd58cc78c3360dcec4ef2b1b001d39 3ffb4753320c22f0ad5b6982a5978ec0 654c7fa542a2afae12d5aff8298f97ab 1a3f3aa7735f9c3377e44e6a45648516 848b854bc2a48c0bf8849e8c8a5dd487 7975fc97d1beaf9eb7484963d2016157 12c29b788c87a9e0a16fb1c6bbd6ad5d 912b8b8375bd616df374c2b82dcdc33c a6ef7856d7c6181870262ad222b75555 2be407e3e38e2a2763e4593264980be8 f70d60af969c8a73a65ba3d1f3609982
# --------------------------------------------------
# blockheight: 8 winner: 2a6669e7f7993c819533877c1455dd7d blockhash: 00018524b396c41a7b733ad757bdb704a76fbd24fb92e8960e52da9168eaf78a
# blockheight: 9 winner: b9a4eae1fddeddf713c775d7ff43ff99 blockhash: 0001f8d4d844197763cce923f77373877c09f94038e64c79c103eda66065570d
# blockheight: 10 winner: b8554490c37801b91ee5509b32364b90 blockhash: 0001607c46e5cc152fcd77ba1d14c14b8e13ba598069c22eb474d9b4cb5f7700
# blockheight: 11 winner: b9a4eae1fddeddf713c775d7ff43ff99 blockhash: 0001a4fdd187b2d41ab4fed86f15d51e18ab10c29f2020239e4a44b172248698
# blockheight: 12 winner: c8e76a9a71ea86150aeed68c32a5507c blockhash: 000132abc83ad0473f645fb64e667d1abc0267ba6632871f20978da94d627f25
# blockheight: 13 winner: c8e76a9a71ea86150aeed68c32a5507c blockhash: 00006156c7a835b3da6a513aeb0d7836eb911960933634baa38d81ddee7cdb2e
# blockheight: 14 winner: 7748a130899903a079a4d630674ae892 blockhash: 000198efc1721db4b6921130a0a0b62c52dbb8d53a1018768972d57f109bb7d0
# blockheight: 15 winner: c8e76a9a71ea86150aeed68c32a5507c blockhash: 00012cd72e9ad1f18c95b6596b4207677a8038fe3399982f2bb27dde2f0ab535
# blockheight: 16 winner: 417bb4ed50894b21207add3526caa834 blockhash: 0000ae5c16eed1e485e1df9938e2cd42c4095909dc78996e9fb25ba53d62bc29
# blockheight: 17 winner: c8e76a9a71ea86150aeed68c32a5507c blockhash: 000179f0457f557251c5924398c306d6ef650b6f959e0ddfd02e43aac39aaeb4
# --------------------------------------------------
# POW_NODES: 5294c1ebe2080717c2c9d737490a01f8 7748a130899903a079a4d630674ae892 d1b76e1c84e64051506efdd21810fa32 d80acc658a535f45c4a3b16136be6f74 097e9804b11ec53f67beff70279b7e2c 7478b3926b58c836436f145d6140d967 3dda79a12d94d5f917ad578ad49265d1 9e6596435f2206a0e61b6214cb5214ba 046a4928312da0e97608622ca0118ff1 417bb4ed50894b21207add3526caa834 c8e76a9a71ea86150aeed68c32a5507c 099f2f73519fbe1190bd53c2d118cda2 b9a4eae1fddeddf713c775d7ff43ff99 323c63c511ff3330fe60026eb999a03c 7b7d03f4cef7e93f5ccd121da41ba6ef 74408035bd9dd31b26c21ad27e224da5 86f3b81c06303cd8a933704846eef197 f0f36615579c8e23ca6c11671ae7213b 6b544a6fd4a82030efcb89b08dd3fe5a 6c6034ac9dd73d53bb4cb8064cce43f7 2a945c61935115458a7a2ef4df5fed9f
# VERYFI_NODES: 1ae67fb99fba9e51d85c2441d2d8be62 8849dbd4fa9e19afa6705a05337eb7dd 0770314e285869e26bd306dae2625ac9 1a3f3aa7735f9c3377e44e6a45648516 cb831523a47e6f671b6f28660c82320a a35e1535d22eb9ab7668d036c9c7df4d 6dc35db4f122fd78538c016ba90e3ad3 912b8b8375bd616df374c2b82dcdc33c a6ef7856d7c6181870262ad222b75555 4ac6b6923f843e926075866cd998892b a7f24dedade12f144196bd120f489f78
# --------------------------------------------------
# blockheight: 18 winner: 7748a130899903a079a4d630674ae892 blockhash: 0000f01a629beea060e5a1093bb35593ee5442b2acdde53705ebd031f03822e4
# blockheight: 19 winner: 099f2f73519fbe1190bd53c2d118cda2 blockhash: 00010133b7e10a723af1b37ea7c94025b6780c01124e4dde7e2094fc24c2cc09
# blockheight: 20 winner: 417bb4ed50894b21207add3526caa834 blockhash: 000022186acc48a0941360bb2169f25b6aebea2c12c09f3071b9af78122adbbd
# blockheight: 21 winner: 323c63c511ff3330fe60026eb999a03c blockhash: 000113385bce9180460d039c72ca7b08dc330302ccc538000d47e28095ba0be1
# blockheight: 22 winner: 74408035bd9dd31b26c21ad27e224da5 blockhash: 000129f98626c326e73cbea1128b7e87431b18b0aebc47939c404a16274dac3f
# blockheight: 23 winner: c8e76a9a71ea86150aeed68c32a5507c blockhash: 00009fbe78a3d6215709bc03baa05ab7f3f684bfb84277a63cb020084dc9a53b
# blockheight: 24 winner: 74408035bd9dd31b26c21ad27e224da5 blockhash: 0001bac69330d486f643c97c9f32eecd53d2000b4c5aec54aab4222f4a22a5d1
# blockheight: 25 winner: 417bb4ed50894b21207add3526caa834 blockhash: 00014568fe31675fc822dce088d9eaff80b7ea610e94efb283b8c2270920496f
# blockheight: 26 winner: 323c63c511ff3330fe60026eb999a03c blockhash: 00005be91167fb0b3983ee668e5880505967e14ff931b59d7a1295adace63462
# blockheight: 27 winner: 74408035bd9dd31b26c21ad27e224da5 blockhash: 00018cea6eeb30d31835539f24b8de8c321e58c653735bb26a82a5769814b2e8
# --------------------------------------------------
# POW_NODES: af15d2a6cc7c5215ebe44921f11e43ae 216545b14e2fd0c3754a52ad24966f3d e3c27b7ccbc4771f822caac042099968 d80acc658a535f45c4a3b16136be6f74 fdb577ba13cf43bf9445a119883f6161 89bd8727266a9671aa276ca0f121a77f 955c3db4c8bf5c990e729b08307535c0 1a2d7e4bdc48de3854a16387f12db2ec 046a4928312da0e97608622ca0118ff1 417bb4ed50894b21207add3526caa834 e67734aaa97973766da148b3ff9729fe f8ffb6f8d05db4f069ed2f61c0b30358 b386f18c4159d4986c3eec0f18cc2aa7 323c63c511ff3330fe60026eb999a03c 22f7cfb4c5902d998ec623fe715b81a3 74408035bd9dd31b26c21ad27e224da5 5285a93e7b2bd4d3bf823ef6d0ba75bb f0f36615579c8e23ca6c11671ae7213b 1268e833c4643187545355f9bdee1795 7ce4d1570fd82f4ae2805ba0c4c0cb16 00283c6a98b2bbcaf7b47ae33a5ea8dd
# VERYFI_NODES: d93ceae5ddb808795a0c5788ed9e74e4 3ffb4753320c22f0ad5b6982a5978ec0 a64e05a229e149a9e4b6421c00b4db6c e141c355b3ddde2ffb928453e4ac98c3 848b854bc2a48c0bf8849e8c8a5dd487 a35e1535d22eb9ab7668d036c9c7df4d b0b99ce94a3db8a6dcb857d37f62c004 912b8b8375bd616df374c2b82dcdc33c a6ef7856d7c6181870262ad222b75555 2be407e3e38e2a2763e4593264980be8 52ec1e92329ea5bd31de8987351a06ca
# --------------------------------------------------
# blockheight: 28 winner: 216545b14e2fd0c3754a52ad24966f3d blockhash: 00015397dd3a29759096c4871e3cdf8227434f5da898324bd5662922b46549f0
# blockheight: 29 winner: 417bb4ed50894b21207add3526caa834 blockhash: 0001773f52590ebc73f997e854c6cb59c6067b657bb905386fb36eadb3be4c1e
# blockheight: 30 winner: e67734aaa97973766da148b3ff9729fe blockhash: 00011cb9d40a129dc76cf5b1faad65c83a1a05f39749c2aa92b02031f747a502
# blockheight: 31 winner: 417bb4ed50894b21207add3526caa834 blockhash: 00005f12811f02b220faaa3bc26776758c7b862d1950f4e99e5d7c7fb98d88f6
# blockheight: 32 winner: af15d2a6cc7c5215ebe44921f11e43ae blockhash: 0000326485c46d4c46dc7a8a08ed455637757b749f00ea42d256c54a51066e44
# blockheight: 33 winner: b386f18c4159d4986c3eec0f18cc2aa7 blockhash: 00006e8a7c76f54b7d6bdb4b89a569397ad2376c13927a45043667d1e588178d
# blockheight: 34 winner: e67734aaa97973766da148b3ff9729fe blockhash: 0001b9949f52ce426f2af6e2f075deeb43f8d73350cd1fedc0cce7e918e2df55
# blockheight: 35 winner: b386f18c4159d4986c3eec0f18cc2aa7 blockhash: 0001f0c9dadaa7b46942f97c5f60ac72cb36de129b43ca1957d828eb1c54fe1e
# blockheight: 36 winner: 216545b14e2fd0c3754a52ad24966f3d blockhash: 0001d72fff16a2251b953e565af088bce3d0f90b0fc45111e642f9eee418eb17
# blockheight: 37 winner: 417bb4ed50894b21207add3526caa834 blockhash: 00007e3f450685c2091aa971a2a1a528b856bc5ebec9c021f5c865ee1eb0879f
# --------------------------------------------------
# POW_NODES: 5294c1ebe2080717c2c9d737490a01f8 7748a130899903a079a4d630674ae892 d1b76e1c84e64051506efdd21810fa32 d80acc658a535f45c4a3b16136be6f74 097e9804b11ec53f67beff70279b7e2c 89bd8727266a9671aa276ca0f121a77f e26fcb9daf7c1de62137b5454b4cf555 08fea26bf6e6c5df11838b807a338999 2a6669e7f7993c819533877c1455dd7d 417bb4ed50894b21207add3526caa834 c8e76a9a71ea86150aeed68c32a5507c 40f8329121414e071840d5ce0e826262 b9a4eae1fddeddf713c775d7ff43ff99 b8554490c37801b91ee5509b32364b90 22f7cfb4c5902d998ec623fe715b81a3 99cdd208b8bafae050bb66e786e5d5d1 86f3b81c06303cd8a933704846eef197 01073ee15582cd5b489ce252671244a7 1268e833c4643187545355f9bdee1795 7ce4d1570fd82f4ae2805ba0c4c0cb16 cffe488e8713e14c1b889a1b1c8288ec
# VERYFI_NODES: d93ceae5ddb808795a0c5788ed9e74e4 8849dbd4fa9e19afa6705a05337eb7dd a64e05a229e149a9e4b6421c00b4db6c e141c355b3ddde2ffb928453e4ac98c3 cb831523a47e6f671b6f28660c82320a 7975fc97d1beaf9eb7484963d2016157 b0b99ce94a3db8a6dcb857d37f62c004 5f4d4ee54c8fb675bbacfaa1546291f6 a6ef7856d7c6181870262ad222b75555 4ac6b6923f843e926075866cd998892b f70d60af969c8a73a65ba3d1f3609982
# --------------------------------------------------
# blockheight: 38 winner: 7748a130899903a079a4d630674ae892 blockhash: 0000db51931ec33385b59d9757f8f43a74e3dc4aa7e6c66fd3e05192327f580a
# blockheight: 39 winner: 417bb4ed50894b21207add3526caa834 blockhash: 0001d1685271354b6435d0c3839aee9216ea1a2bfc1a6daf15f61c7ecdbfbea3
# blockheight: 40 winner: b9a4eae1fddeddf713c775d7ff43ff99 blockhash: 0000d3e1e6b9154a1f929610a0cee05eee6f1a9545953e9509493e64b7cc3a99
# blockheight: 41 winner: c8e76a9a71ea86150aeed68c32a5507c blockhash: 00008a8b4fa191861cf7818154d57cf6eace5446cd3f343a056d679f2fab2473
# blockheight: 42 winner: b8554490c37801b91ee5509b32364b90 blockhash: 00009d0e52e258d81838db767b63258447388be27dc34a70db549f52d974d5ab
# blockheight: 43 winner: 5294c1ebe2080717c2c9d737490a01f8 blockhash: 0000b406faaa9e6e71ccc5afa9a18ce0de83cb3c5648d85889b102867493d767
# blockheight: 44 winner: b8554490c37801b91ee5509b32364b90 blockhash: 0001a723be0e0f3af6de9080d61a1a6ca29eb050aea6fe7c92672534bc8682e1
# blockheight: 45 winner: 417bb4ed50894b21207add3526caa834 blockhash: 0000e2c210c712314894f0d9b594ec1e234b73a3ce3d450c75d305b9be83d2eb
# blockheight: 46 winner: 40f8329121414e071840d5ce0e826262 blockhash: 00001da0034de3ac29a3d226874602290250ed6015b8117959f0bac9c51d7806
# blockheight: 47 winner: 40f8329121414e071840d5ce0e826262 blockhash: 00005da9b6ea45443b40efb5b40db1b6ae232f88e71949641e0257c79f76d35d
# --------------------------------------------------
# POW_NODES: 5294c1ebe2080717c2c9d737490a01f8 7748a130899903a079a4d630674ae892 d1b76e1c84e64051506efdd21810fa32 d80acc658a535f45c4a3b16136be6f74 097e9804b11ec53f67beff70279b7e2c 7c455fe84557fae40188787df071dc67 955c3db4c8bf5c990e729b08307535c0 9e6596435f2206a0e61b6214cb5214ba da07df218e5ed6b455ee31dc328b2960 21dd29b38d6627b0b573366149c6d837 ee0042006293912079df44d7da899c5c 099f2f73519fbe1190bd53c2d118cda2 b9a4eae1fddeddf713c775d7ff43ff99 323c63c511ff3330fe60026eb999a03c 22f7cfb4c5902d998ec623fe715b81a3 99cdd208b8bafae050bb66e786e5d5d1 86f3b81c06303cd8a933704846eef197 6ffe644343e42e5fd3b151700426a6df 6b544a6fd4a82030efcb89b08dd3fe5a 6c6034ac9dd73d53bb4cb8064cce43f7 2a945c61935115458a7a2ef4df5fed9f
# VERYFI_NODES: 1ae67fb99fba9e51d85c2441d2d8be62 8849dbd4fa9e19afa6705a05337eb7dd 654c7fa542a2afae12d5aff8298f97ab e141c355b3ddde2ffb928453e4ac98c3 cb831523a47e6f671b6f28660c82320a 38162b83d5fdf3a5fa8819ec48d7f59c 12c29b788c87a9e0a16fb1c6bbd6ad5d 5f4d4ee54c8fb675bbacfaa1546291f6 204caba53c30d86b429d617a7dc92788 2be407e3e38e2a2763e4593264980be8 52ec1e92329ea5bd31de8987351a06ca
# --------------------------------------------------
# blockheight: 48 winner: ee0042006293912079df44d7da899c5c blockhash: 00009089e74025931bff42c566f15942f5a878bb63ddcd4b072690401b10f2ce
# blockheight: 49 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 000119dc01ff0e73790442e6b4426ba42f7f4ba6286a55dd98f663ace15e934e
# blockheight: 50 winner: b9a4eae1fddeddf713c775d7ff43ff99 blockhash: 0000774b150fc4b55dece1146ba66dbbb83c23fe6580734433faa8e8fcd7b1d6
# blockheight: 51 winner: 6ffe644343e42e5fd3b151700426a6df blockhash: 0001cc425a09b50e7e8763d123f57f90a71e5b0443894db634fe8f48dcbdbba0
# blockheight: 52 winner: 22f7cfb4c5902d998ec623fe715b81a3 blockhash: 0001fcaf57434b0e0ac2d3b31e67dacba1ad89969d9b2ae5fb7e64c51a0af2b4
# blockheight: 53 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 00005b6753e0881c9160ea2e3114d36ebf2e20c699facdc996b1202fadaad43e
# blockheight: 54 winner: ee0042006293912079df44d7da899c5c blockhash: 0000481d4d3ec6273a0c71dbeb5912e9967ac30b7e93adbcd68bb14c65e84bbc
# blockheight: 55 winner: ee0042006293912079df44d7da899c5c blockhash: 000122132bb09cb4a34ca6b133f0e459dc41d7a9bb38802bb587778cc3cb08bb
# blockheight: 56 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 000040036c7e64403c59a8a7eb3549db1d339218740438f311ff74d4d45f252b
# blockheight: 57 winner: b9a4eae1fddeddf713c775d7ff43ff99 blockhash: 00012cee3fbd0602f9d59b8d69ffe7c5de06cfde74ae44799fdb4b4ec83ba6e5
# --------------------------------------------------
# POW_NODES: af15d2a6cc7c5215ebe44921f11e43ae 216545b14e2fd0c3754a52ad24966f3d d1b76e1c84e64051506efdd21810fa32 d80acc658a535f45c4a3b16136be6f74 097e9804b11ec53f67beff70279b7e2c 7478b3926b58c836436f145d6140d967 e26fcb9daf7c1de62137b5454b4cf555 1a2d7e4bdc48de3854a16387f12db2ec 2a6669e7f7993c819533877c1455dd7d 7c777924f9bfb205155e5a3d633707f9 ee0042006293912079df44d7da899c5c 099f2f73519fbe1190bd53c2d118cda2 9cce0c3209b0a0c3f2923036c0fb6c97 2ba77a982749bf7a223d6baa49bcf175 7b7d03f4cef7e93f5ccd121da41ba6ef faa5f30090ec9fde5226d0455becdc4a 86f3b81c06303cd8a933704846eef197 01073ee15582cd5b489ce252671244a7 1268e833c4643187545355f9bdee1795 7ce4d1570fd82f4ae2805ba0c4c0cb16 00283c6a98b2bbcaf7b47ae33a5ea8dd
# VERYFI_NODES: d93ceae5ddb808795a0c5788ed9e74e4 3ffb4753320c22f0ad5b6982a5978ec0 0770314e285869e26bd306dae2625ac9 e141c355b3ddde2ffb928453e4ac98c3 3f269e74e9ecbfa4b4efcc21032b8205 38162b83d5fdf3a5fa8819ec48d7f59c 6dc35db4f122fd78538c016ba90e3ad3 912b8b8375bd616df374c2b82dcdc33c a6ef7856d7c6181870262ad222b75555 2be407e3e38e2a2763e4593264980be8 a7f24dedade12f144196bd120f489f78
# --------------------------------------------------
# blockheight: 58 winner: 7c777924f9bfb205155e5a3d633707f9 blockhash: 000180df9b47100b15669b23d7a8fb75818f446f0350b56eb39290d22ad5d591
# blockheight: 59 winner: 7c777924f9bfb205155e5a3d633707f9 blockhash: 00007b71ba4aa004c47c0dbd73f51129669414e9a7acf00cc0fa1408e33401f8
# blockheight: 60 winner: 099f2f73519fbe1190bd53c2d118cda2 blockhash: 0001c6196e10ad75b48900d21f68e232716b4496f6a3562eed9f897b516bca8d
# blockheight: 61 winner: 7c777924f9bfb205155e5a3d633707f9 blockhash: 00001146fae87e0b07e81548f7dccbbc116d5b8ce8cd59dfb12fcbd2fc4171c2
# blockheight: 62 winner: ee0042006293912079df44d7da899c5c blockhash: 0001aaad63c7e0d880a42ff8502998ab27d3f27000435e3ccd9f88288a9b9b99
# blockheight: 63 winner: 099f2f73519fbe1190bd53c2d118cda2 blockhash: 000182bfb2dafd968882e2859f0be3eedfe1f0a9e0a43991d478e658f578e46b
# blockheight: 64 winner: 216545b14e2fd0c3754a52ad24966f3d blockhash: 00007c0b2c557d670d80c77bbd57bf59be7fc1609947de3d3f7364b98d860dc4
# blockheight: 65 winner: 7c777924f9bfb205155e5a3d633707f9 blockhash: 00002df2080aa175e2114cb83d8abe21d881026abc46af03224c823cdaf03b8d
# blockheight: 66 winner: ee0042006293912079df44d7da899c5c blockhash: 0000000ab8aada54e043dc47e8bd2d5dc60315ed7877b9e4b8f7bb43de845b35
# blockheight: 67 winner: ee0042006293912079df44d7da899c5c blockhash: 0001049990e6a95e9325d5c3bf0b3a658a77c9ba6865f1faac106ee7c5fb2538
# --------------------------------------------------
# POW_NODES: 845372cdcae4e424e91d9388eab76ddd 216545b14e2fd0c3754a52ad24966f3d d1b76e1c84e64051506efdd21810fa32 d80acc658a535f45c4a3b16136be6f74 6eb511e81888f0d083e5c3ad50c05fc1 7478b3926b58c836436f145d6140d967 955c3db4c8bf5c990e729b08307535c0 9e6596435f2206a0e61b6214cb5214ba 046a4928312da0e97608622ca0118ff1 417bb4ed50894b21207add3526caa834 e67734aaa97973766da148b3ff9729fe 40f8329121414e071840d5ce0e826262 b9a4eae1fddeddf713c775d7ff43ff99 323c63c511ff3330fe60026eb999a03c 22f7cfb4c5902d998ec623fe715b81a3 faa5f30090ec9fde5226d0455becdc4a 5285a93e7b2bd4d3bf823ef6d0ba75bb 6ffe644343e42e5fd3b151700426a6df 1268e833c4643187545355f9bdee1795 591645eb4cd47d94885b14bfb23c1712 00283c6a98b2bbcaf7b47ae33a5ea8dd
# VERYFI_NODES: 1ae67fb99fba9e51d85c2441d2d8be62 8849dbd4fa9e19afa6705a05337eb7dd 654c7fa542a2afae12d5aff8298f97ab e141c355b3ddde2ffb928453e4ac98c3 848b854bc2a48c0bf8849e8c8a5dd487 a35e1535d22eb9ab7668d036c9c7df4d 6dc35db4f122fd78538c016ba90e3ad3 912b8b8375bd616df374c2b82dcdc33c a6ef7856d7c6181870262ad222b75555 2be407e3e38e2a2763e4593264980be8 f70d60af969c8a73a65ba3d1f3609982
# --------------------------------------------------
# blockheight: 68 winner: 323c63c511ff3330fe60026eb999a03c blockhash: 00013b5b4c66026e1cb8c9c721ff029cf72ab7205904a3a592d56e4e4aa9a837
# blockheight: 69 winner: 323c63c511ff3330fe60026eb999a03c blockhash: 0001ebb0ea384af19a11306f7771f1c7c4c720d9bef986e0ca25b37b373916b8
# blockheight: 70 winner: b9a4eae1fddeddf713c775d7ff43ff99 blockhash: 0000f5f8e9262f5fcfb1044cba63a416728f05b181756146d894c1cdc650fcd9
# blockheight: 71 winner: 417bb4ed50894b21207add3526caa834 blockhash: 00001c8d17580a1a15412b267448b816fee6a2c18eaa44eacdab9563ea9dfad8
# blockheight: 72 winner: 323c63c511ff3330fe60026eb999a03c blockhash: 00015d21e88cb4a4fda768852776830c158200b75d63687ba467e66247eb232f
# blockheight: 73 winner: b9a4eae1fddeddf713c775d7ff43ff99 blockhash: 000063bd807bb887d1425281ca59122e1d8e5681b84f7118704c7a575459d66b
# blockheight: 74 winner: 417bb4ed50894b21207add3526caa834 blockhash: 000061d856c0ac2a103e4a0018287a07048531bf45183493f06391052957c11c
# blockheight: 75 winner: 40f8329121414e071840d5ce0e826262 blockhash: 000187fd23623d2d10ea82524104c39599a400bab660386d63be08fb749ac5af
# blockheight: 76 winner: faa5f30090ec9fde5226d0455becdc4a blockhash: 0001af07aad97fc63594c5025f8a6534f89c82d386501ae085a02b563c889b3d
# blockheight: 77 winner: 40f8329121414e071840d5ce0e826262 blockhash: 00014a317cf0f427193e01266708c92facf0d95e224cd2d0bfcc58eb4b907ab5
# --------------------------------------------------
# POW_NODES: af15d2a6cc7c5215ebe44921f11e43ae 216545b14e2fd0c3754a52ad24966f3d d1b76e1c84e64051506efdd21810fa32 bb0f34a49c1412f5baae54ba78c34c56 097e9804b11ec53f67beff70279b7e2c 89bd8727266a9671aa276ca0f121a77f 955c3db4c8bf5c990e729b08307535c0 08fea26bf6e6c5df11838b807a338999 da07df218e5ed6b455ee31dc328b2960 21dd29b38d6627b0b573366149c6d837 e67734aaa97973766da148b3ff9729fe 40f8329121414e071840d5ce0e826262 b9a4eae1fddeddf713c775d7ff43ff99 2ba77a982749bf7a223d6baa49bcf175 22f7cfb4c5902d998ec623fe715b81a3 74408035bd9dd31b26c21ad27e224da5 5285a93e7b2bd4d3bf823ef6d0ba75bb f0f36615579c8e23ca6c11671ae7213b 6b544a6fd4a82030efcb89b08dd3fe5a 6c6034ac9dd73d53bb4cb8064cce43f7 cffe488e8713e14c1b889a1b1c8288ec
# VERYFI_NODES: 1ae67fb99fba9e51d85c2441d2d8be62 3ffb4753320c22f0ad5b6982a5978ec0 0770314e285869e26bd306dae2625ac9 8e5e3ec75ff9c1c4bf1fda6aeb9e65e4 848b854bc2a48c0bf8849e8c8a5dd487 a35e1535d22eb9ab7668d036c9c7df4d 12c29b788c87a9e0a16fb1c6bbd6ad5d aa797b7971a7bc72e859e8cb99267d61 ab23e948a62ad73759597daea1531eaf 4ac6b6923f843e926075866cd998892b a7f24dedade12f144196bd120f489f78
# --------------------------------------------------
# blockheight: 78 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 000144daba9a90e9092f451347d392fa3bd3c6d4c7c837d48c93dd97a1392c97
# blockheight: 79 winner: 22f7cfb4c5902d998ec623fe715b81a3 blockhash: 0001beddf7b5049b6fe879059248e43d940958b1a0711cbfa478abd2f2f1d132
# blockheight: 80 winner: e67734aaa97973766da148b3ff9729fe blockhash: 0000caffe6ecac24a18dcaab0ffb99aef24d843447316124b8cdaaf903397e9f
# blockheight: 81 winner: e67734aaa97973766da148b3ff9729fe blockhash: 0000dbdd81bf8d113343a8f22c946dc5cd9430a51ffaeb30e0e259143058c975
# blockheight: 82 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 0001b1d37376ba86803a14ea9e287440566b2d2dec3a0980107b1a8dc3258999
# blockheight: 83 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 0001a3dfc247447eb16d574e5079dc94682e51ba2e3221982d0ab772168ffe71
# blockheight: 84 winner: 2ba77a982749bf7a223d6baa49bcf175 blockhash: 000021239ed4ca643c8e9e5658c6c1ee91f5e39a68be23ca065ca24870ae72f9
# blockheight: 85 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 00019353666c9a71f750b69466f8c163211f840d43e96902458f47ef827980f1
# blockheight: 86 winner: e67734aaa97973766da148b3ff9729fe blockhash: 000039961e54f33be45d12c2c74779a9c49b606efbf8ac02bd1d39843eb2320e
# blockheight: 87 winner: af15d2a6cc7c5215ebe44921f11e43ae blockhash: 0001cd04ccb230b7683682dd5c87ecfd79a004fa708a259e8c209e18921a2c94
# --------------------------------------------------
# POW_NODES: 845372cdcae4e424e91d9388eab76ddd 7748a130899903a079a4d630674ae892 8ce7576cc7ffffd85e0c619c54121542 0e2beadba5a03c4b25c26352e7b1178e 6eb511e81888f0d083e5c3ad50c05fc1 7478b3926b58c836436f145d6140d967 3dda79a12d94d5f917ad578ad49265d1 1a2d7e4bdc48de3854a16387f12db2ec 046a4928312da0e97608622ca0118ff1 417bb4ed50894b21207add3526caa834 ee0042006293912079df44d7da899c5c 099f2f73519fbe1190bd53c2d118cda2 b9a4eae1fddeddf713c775d7ff43ff99 323c63c511ff3330fe60026eb999a03c 670629036d25769e5d31c350f2e58051 74408035bd9dd31b26c21ad27e224da5 86f3b81c06303cd8a933704846eef197 6ffe644343e42e5fd3b151700426a6df 572fffee8ff77420d34ca8716e76776b 7ce4d1570fd82f4ae2805ba0c4c0cb16 cffe488e8713e14c1b889a1b1c8288ec
# VERYFI_NODES: 1ae67fb99fba9e51d85c2441d2d8be62 3ffb4753320c22f0ad5b6982a5978ec0 654c7fa542a2afae12d5aff8298f97ab 1a3f3aa7735f9c3377e44e6a45648516 cb831523a47e6f671b6f28660c82320a 7975fc97d1beaf9eb7484963d2016157 b0b99ce94a3db8a6dcb857d37f62c004 912b8b8375bd616df374c2b82dcdc33c ab23e948a62ad73759597daea1531eaf ad5573630c3295af2c4f57efea440215 a7f24dedade12f144196bd120f489f78
# --------------------------------------------------
# blockheight: 88 winner: 845372cdcae4e424e91d9388eab76ddd blockhash: 00008d5b2059463731364b101ecead955e0e7cebcd82f8900866a8c8caaed168
# blockheight: 89 winner: 099f2f73519fbe1190bd53c2d118cda2 blockhash: 000123f19fa9e958d8a638be8dc357cdcec8999536e365276308e9419a2e789d
# blockheight: 90 winner: 099f2f73519fbe1190bd53c2d118cda2 blockhash: 0001e8125926357e2178c6f09a69ee6af85937e5b082c03ad4c75929ca85b3eb
# blockheight: 91 winner: 417bb4ed50894b21207add3526caa834 blockhash: 00004d618cefc5fdbf47b13d18c5a40f46d6743a09d4bcf205ef4953f9166492
# blockheight: 92 winner: 7748a130899903a079a4d630674ae892 blockhash: 0000b305a3248681f2dc20fd8afcbc3108b74169535bd2c35c9f0b77135ba727
# blockheight: 93 winner: 323c63c511ff3330fe60026eb999a03c blockhash: 00001aa53d9afcb3ab980df33706357d19b34975ae2baafa0c546f4d9a232d70
# blockheight: 94 winner: 6ffe644343e42e5fd3b151700426a6df blockhash: 0000296b2bd1ae6d7a520f708c7d83e5a321bba00d43b1ce9fe922fbce0e142f
# blockheight: 95 winner: ee0042006293912079df44d7da899c5c blockhash: 000089d263ade1b38fbebc11c49239d09fcd0aec24eb0fe3755500e4e2185d07
# blockheight: 96 winner: 417bb4ed50894b21207add3526caa834 blockhash: 00010c196af15c5fde903b90206f98c4ab841419834049728974e217e3b5bf99
# blockheight: 97 winner: 323c63c511ff3330fe60026eb999a03c blockhash: 00013e3a19f3c996a7aa46b290349f2d95b434175c2ea9bf426397dbddc59ec9
# --------------------------------------------------
# POW_NODES: 845372cdcae4e424e91d9388eab76ddd 216545b14e2fd0c3754a52ad24966f3d d1b76e1c84e64051506efdd21810fa32 d80acc658a535f45c4a3b16136be6f74 6eb511e81888f0d083e5c3ad50c05fc1 89bd8727266a9671aa276ca0f121a77f 955c3db4c8bf5c990e729b08307535c0 08fea26bf6e6c5df11838b807a338999 2a6669e7f7993c819533877c1455dd7d 21dd29b38d6627b0b573366149c6d837 c8e76a9a71ea86150aeed68c32a5507c 099f2f73519fbe1190bd53c2d118cda2 b9a4eae1fddeddf713c775d7ff43ff99 b8554490c37801b91ee5509b32364b90 22f7cfb4c5902d998ec623fe715b81a3 faa5f30090ec9fde5226d0455becdc4a 5285a93e7b2bd4d3bf823ef6d0ba75bb 01073ee15582cd5b489ce252671244a7 6b544a6fd4a82030efcb89b08dd3fe5a 591645eb4cd47d94885b14bfb23c1712 cffe488e8713e14c1b889a1b1c8288ec
# VERYFI_NODES: d93ceae5ddb808795a0c5788ed9e74e4 8849dbd4fa9e19afa6705a05337eb7dd 654c7fa542a2afae12d5aff8298f97ab e141c355b3ddde2ffb928453e4ac98c3 3f269e74e9ecbfa4b4efcc21032b8205 a35e1535d22eb9ab7668d036c9c7df4d 6dc35db4f122fd78538c016ba90e3ad3 5f4d4ee54c8fb675bbacfaa1546291f6 204caba53c30d86b429d617a7dc92788 ad5573630c3295af2c4f57efea440215 f70d60af969c8a73a65ba3d1f3609982
# --------------------------------------------------
# blockheight: 98 winner: 21dd29b38d6627b0b573366149c6d837 blockhash: 000131dbdcb273d431830b494582a86470e168b0def35c37ce3b273037cd306a
# blockheight: 99 winner: c8e76a9a71ea86150aeed68c32a5507c blockhash: 0001b66292d33542ab215f41562b524a2e4ac69ba06095bbf911cc357d1be9b1
# blockheight: 100 winner: 216545b14e2fd0c3754a52ad24966f3d blockhash: 000159dcee4040218c2b8979c890b752f97a6fd646798455f8846401176f5954
